# %% [markdown]
# <a href="https://colab.research.google.com/github/addy01l/lecture/blob/main/AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def chatbot():
    print("Hello!")

    while True:
        n = input("You: ").lower()
        if n == "quit":
            print("Chatbot: Goodbye!")
            break

        response_text = "I'm sorry, I don't understand that question."
        if n == "hello":
            response_text = "Hi"
        elif n == "how are you":
            response_text = " I'm ready to assist you!"
        elif n == "what is your name":
            response_text = "I am a simple chatbot."
        elif n == "bye":
            response_text = "Goodbye! "
        elif n == "thanks":
            response_text = "You're welcome!"

        print(f"Chatbot: {response_text}")

chatbot()
